# %%
import pandas as pd

output = pd.read_excel("output.xlsx")

# %%
# переименовываем колонки
output = output.rename(
    columns={
        "Долгота": "lat",
        "Широта": "lon"
    }
)

# сбрасываем индекс
output = output.reset_index(drop=True)

output
# Out:
#                                          Полный адресс        lat        lon
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2               Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 3    Лесные Поляны 5-я ул., з/у 20А, к. 1  Рябиновы...  55.961258  37.849508
# 4                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# ..                                                 ...        ...        ...
# 416          Лаптева ул., з/у 2, к. 3   7 оч., сек. 2   58.741440  61.594267
# 417                            Рязановское п., к. 11.2  53.938518  49.359994
# 418                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 419    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 420                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
# [421 rows x 3 columns]

# %%
output
# Out:
#                                          Полный адресс    Долгота     Широта
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2               Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 3    Лесные Поляны 5-я ул., з/у 20А, к. 1  Рябиновы...  55.961258  37.849508
# 4                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# ..                                                 ...        ...        ...
# 416          Лаптева ул., з/у 2, к. 3   7 оч., сек. 2   58.741440  61.594267
# 417                            Рязановское п., к. 11.2  53.938518  49.359994
# 418                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 419    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 420                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
# [421 rows x 3 columns]

# %%
metronew = pd.read_csv("newmetro.csv")
metronew
# Out:
#      Линия  Код станции[1]                 Название станции\nПрежние названия  \
# 0      NaN               1  «Бульвар Рокоссовского»\nУлица Подбельского (с...
# 1      NaN               2                                     «Черкизовская»
# 2      NaN               3                           «Преображенская площадь»
# 3      NaN               4                                       «Сокольники»
# 4      NaN               5                                   «Красносельская»
# ..     ...             ...                                                ...
# 268    NaN             332                                «Генерала Тюленева»
# 269    NaN             333                                       «Тютчевская»
# 270    NaN             335                                     «Корниловская»
# 271    NaN             334                                       «Коммунарка»
# 272    NaN             336                                   «Новомосковская»
#
#       Дата\nоткрытия Пере-\nсадки Глубина,\nм[2]  \
# 0     1 августа 1990          NaN             −8
# 1     1 августа 1990          NaN             −9
# 2    31 декабря 1965          NaN             −8
# 3        15 мая 1935          NaN             −9
# 4        15 мая 1935          NaN             −8
# ..               ...          ...            ...
# 268  7 сентября 2024          NaN            -20
# 269  7 сентября 2024          NaN         -12,65
# 270  28 декабря 2024          NaN         -16,18
# 271  28 декабря 2024          NaN            -15
# 272  28 декабря 2024          NaN             -8
#
#                                 Тип конструкции  \
# 0    колонная\nмелкого заложения\nтрёхпролётная
# 1              односводчатая\nмелкого заложения
# 2    колонная\nмелкого заложения\nтрёхпролётная
# 3    колонная\nмелкого заложения\nтрёхпролётная
# 4    колонная\nмелкого заложения\nдвухпролётная
# ..                                          ...
# 268  колонная\nмелкого заложения\nтрёхпролётная
# 269  колонная\nмелкого заложения\nтрёхпролётная
# 270  колонная\nмелкого заложения\nтрёхпролётная
# 271  колонная\nмелкого заложения\nдвухпролётная
# 272            односводчатая\nмелкого заложения
#
#                             Координаты  Вид станции
# 0    55°48′53″ с. ш. 37°44′03″ в. д.HЯ          NaN
# 1    55°48′14″ с. ш. 37°44′41″ в. д.HЯ          NaN
# 2    55°47′47″ с. ш. 37°42′54″ в. д.HЯ          NaN
# 3    55°47′20″ с. ш. 37°40′49″ в. д.HЯ          NaN
# 4    55°46′48″ с. ш. 37°40′02″ в. д.HЯ          NaN
# ..                                 ...          ...
# 268  55°37′34″ с. ш. 37°29′10″ в. д.HЯ          NaN
# 269  55°37′08″ с. ш. 37°28′52″ в. д.HЯ          NaN
# 270  55°35′56″ с. ш. 37°28′45″ в. д.HЯ          NaN
# 271  55°34′29″ с. ш. 37°28′05″ в. д.HЯ          NaN
# 272  55°33′38″ с. ш. 37°27′55″ в. д.HЯ          NaN
#
# [273 rows x 9 columns]

# %%
import re

import re

def dms_to_decimal(dms):
    nums = list(map(float, re.findall(r"\d+", dms)))
    deg, minute, sec = nums[:3]
    return deg + minute / 60 + sec / 3600

metronew["название"] = (
    metronew["Название станции\nПрежние названия"]
    .str.split("\n")
    .str[0]
    .str.replace("«|»", "", regex=True)
)

def extract_lat_lon(s):
    lat_dms = re.search(r"(\d+°\d+′\d+″)\s*с\.?\s*ш\.?", s)
    lon_dms = re.search(r"(\d+°\d+′\d+″)\s*в\.?\s*д\.?", s)

    lat = dms_to_decimal(lat_dms.group(1)) if lat_dms else None
    lon = dms_to_decimal(lon_dms.group(1)) if lon_dms else None

    return pd.Series([lat, lon])

metronew[["lat", "lon"]] = metronew["Координаты"].apply(extract_lat_lon)
metronew
# Out:
#      Линия  Код станции[1]                 Название станции\nПрежние названия  \
# 0      NaN               1  «Бульвар Рокоссовского»\nУлица Подбельского (с...
# 1      NaN               2                                     «Черкизовская»
# 2      NaN               3                           «Преображенская площадь»
# 3      NaN               4                                       «Сокольники»
# 4      NaN               5                                   «Красносельская»
# ..     ...             ...                                                ...
# 268    NaN             332                                «Генерала Тюленева»
# 269    NaN             333                                       «Тютчевская»
# 270    NaN             335                                     «Корниловская»
# 271    NaN             334                                       «Коммунарка»
# 272    NaN             336                                   «Новомосковская»
#
#       Дата\nоткрытия Пере-\nсадки Глубина,\nм[2]  \
# 0     1 августа 1990          NaN             −8
# 1     1 августа 1990          NaN             −9
# 2    31 декабря 1965          NaN             −8
# 3        15 мая 1935          NaN             −9
# 4        15 мая 1935          NaN             −8
# ..               ...          ...            ...
# 268  7 сентября 2024          NaN            -20
# 269  7 сентября 2024          NaN         -12,65
# 270  28 декабря 2024          NaN         -16,18
# 271  28 декабря 2024          NaN            -15
# 272  28 декабря 2024          NaN             -8
#
#                                 Тип конструкции  \
# 0    колонная\nмелкого заложения\nтрёхпролётная
# 1              односводчатая\nмелкого заложения
# 2    колонная\nмелкого заложения\nтрёхпролётная
# 3    колонная\nмелкого заложения\nтрёхпролётная
# 4    колонная\nмелкого заложения\nдвухпролётная
# ..                                          ...
# 268  колонная\nмелкого заложения\nтрёхпролётная
# 269  колонная\nмелкого заложения\nтрёхпролётная
# 270  колонная\nмелкого заложения\nтрёхпролётная
# 271  колонная\nмелкого заложения\nдвухпролётная
# 272            односводчатая\nмелкого заложения
#
#                             Координаты  Вид станции                название  \
# 0    55°48′53″ с. ш. 37°44′03″ в. д.HЯ          NaN   Бульвар Рокоссовского
# 1    55°48′14″ с. ш. 37°44′41″ в. д.HЯ          NaN            Черкизовская
# 2    55°47′47″ с. ш. 37°42′54″ в. д.HЯ          NaN  Преображенская площадь
# 3    55°47′20″ с. ш. 37°40′49″ в. д.HЯ          NaN              Сокольники
# 4    55°46′48″ с. ш. 37°40′02″ в. д.HЯ          NaN          Красносельская
# ..                                 ...          ...                     ...
# 268  55°37′34″ с. ш. 37°29′10″ в. д.HЯ          NaN       Генерала Тюленева
# 269  55°37′08″ с. ш. 37°28′52″ в. д.HЯ          NaN              Тютчевская
# 270  55°35′56″ с. ш. 37°28′45″ в. д.HЯ          NaN            Корниловская
# 271  55°34′29″ с. ш. 37°28′05″ в. д.HЯ          NaN              Коммунарка
# 272  55°33′38″ с. ш. 37°27′55″ в. д.HЯ          NaN          Новомосковская
#
#            lat        lon
# 0    55.814722  37.734167
# 1    55.803889  37.744722
# 2    55.796389  37.715000
# 3    55.788889  37.680278
# 4    55.780000  37.667222
# ..         ...        ...
# 268  55.626111  37.486111
# 269  55.618889  37.481111
# 270  55.598889  37.479167
# 271  55.574722  37.468056
# 272  55.560556  37.465278
#
# [273 rows x 12 columns]

# %%
finalmetro = metronew[["название", "lat", "lon"]]
finalmetro
# Out:
#                    название        lat        lon
# 0     Бульвар Рокоссовского  55.814722  37.734167
# 1              Черкизовская  55.803889  37.744722
# 2    Преображенская площадь  55.796389  37.715000
# 3                Сокольники  55.788889  37.680278
# 4            Красносельская  55.780000  37.667222
# ..                      ...        ...        ...
# 268       Генерала Тюленева  55.626111  37.486111
# 269              Тютчевская  55.618889  37.481111
# 270            Корниловская  55.598889  37.479167
# 271              Коммунарка  55.574722  37.468056
# 272          Новомосковская  55.560556  37.465278
#
# [273 rows x 3 columns]

# %%
import numpy as np
import pandas as pd

def haversine_km(lat1, lon1, lat2, lon2):
    # lat1/lon1: (n,1), lat2/lon2: (1,m)
    R = 6371.0088
    lat1 = np.deg2rad(lat1); lon1 = np.deg2rad(lon1)
    lat2 = np.deg2rad(lat2); lon2 = np.deg2rad(lon2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# на всякий случай приводим к числам
output["lat"] = pd.to_numeric(output["lat"], errors="coerce")
output["lon"] = pd.to_numeric(output["lon"], errors="coerce")
finalmetro["lat"] = pd.to_numeric(finalmetro["lat"], errors="coerce")
finalmetro["lon"] = pd.to_numeric(finalmetro["lon"], errors="coerce")

# матрица расстояний n x m
lat_o = output["lat"].to_numpy()[:, None]
lon_o = output["lon"].to_numpy()[:, None]
lat_m = finalmetro["lat"].to_numpy()[None, :]
lon_m = finalmetro["lon"].to_numpy()[None, :]

dist_km = haversine_km(lat_o, lon_o, lat_m, lon_m)

# индекс ближайшего метро для каждой строки output
idx = np.nanargmin(dist_km, axis=1)

output["ближайшее_метро"] = finalmetro["название"].to_numpy()[idx]
output["расстояние_км"] = dist_km[np.arange(dist_km.shape[0]), idx]
output["расстояние_м"] = (output["расстояние_км"] * 1000).round(0).astype("Int64")

output
# Out:
# /var/folders/ws/lrvlpqj171xc51myg0jksgdr0000gn/T/ipykernel_44768/1872267007.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalmetro["lat"] = pd.to_numeric(finalmetro["lat"], errors="coerce")
# /var/folders/ws/lrvlpqj171xc51myg0jksgdr0000gn/T/ipykernel_44768/1872267007.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalmetro["lon"] = pd.to_numeric(finalmetro["lon"], errors="coerce")
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2               Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 3    Лесные Поляны 5-я ул., з/у 20А, к. 1  Рябиновы...  55.961258  37.849508
# 4                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# ..                                                 ...        ...        ...
# 416          Лаптева ул., з/у 2, к. 3   7 оч., сек. 2   58.741440  61.594267
# 417                            Рязановское п., к. 11.2  53.938518  49.359994
# 418                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 419    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 420                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 2             Пыхтино       1.448388          1448
# 3          Медведково      14.322433         14322
# 4          Коммунарка       0.235279           235
# ..                ...            ...           ...
# 416        Некрасовка    1455.864021       1455864
# 417        Некрасовка     757.193015        757193
# 418        Коммунарка       0.668513           669
# 419  Аэропорт Внуково       3.217480          3217
# 420        Коммунарка       0.917124           917
#
# [421 rows x 6 columns]

# %%
fo = output[output["расстояние_км"] < 7]
fo.head(50)
# Out:
#                                         Полный адресс        lat        lon  \
# 0         Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1   Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2              Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 4                    Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 6                  Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# 8                          вблизи Алхимово дер., д. 8  55.475664  37.507313
# 9                                Дудкино дер., к. 1.3  55.630954  37.454259
# 11                      вблизи дер. Середнево, к. 1.1  55.564037  37.289580
# 13             Мосрентген пос., кв-л 24, з/у 1А, к. 2  55.617800  37.472300
# 15             Льва Кассиля ул., д. 1, к. 3  фаза 17   55.637139  37.306423
# 16                      Николо-Хованское дер., д. 6.5  55.593597  37.448598
# 20            Сосенское пос., Столбово дер., к. 3.6.3  55.551128  37.460062
# 21                      вблизи дер. Середнево, к. 1.3  55.564037  37.289580
# 22  Внуковское пос., ТПУ "Рассказовка" тер., з/у 1...  55.632720  37.285688
# 23  Сосенское пос., вблизи Столбово дер., уч. 40/2...  55.548935  37.461364
# 24  вблизи Зимёнки дер., проект 18/2, кв-л 2, к. 3...  55.573164  37.385448
# 25             Столбово дер., з/у 41/1Г, д. 3, к. 3.4  55.562047  37.472027
# 26   Рассказовка дер., кв-л 19, з/у 2, к. 1  фаза 18   55.633953  37.334340
# 27         Александры Монаховой ул., з/у 87, к. 3.7.2  55.541086  37.490551
# 29             Льва Кассиля ул., д. 1, к. 2  фаза 17   55.637139  37.306423
# 31                               Дудкино дер., к. 2.2  55.630583  37.453711
# 34                      Николо-Хованское дер., д. 4.2  55.595024  37.443160
# 35                    Николо-Хованское дер., д. 5.1.1  55.595730  37.444636
# 37                   Александры Монаховой ул., к. 3.4  55.571509  37.477044
# 38                    Николо-Хованское дер., д. 5.1.2  55.595730  37.444636
# 41                     Мосрентген, Дудкино дер., д. 1  55.632989  37.458950
# 42                    Рассказовка дер., д. 15  4 оч.   55.629211  37.336511
# 43  Филимонковское пос., Староселье дер., к. 8  Сити   55.554602  37.316938
# 44             Столбово дер., з/у 41/1Г, д. 2, к. 2.5  55.562398  37.472261
# 45             Столбово дер., з/у 41/1Г, д. 7, к. 7.2  55.561960  37.470860
# 46  Филимонковское пос., ОАО Марьинская птицефабри...  55.565347  37.319921
# 47              Первый Московский мкр., к. 4  11 оч.   55.603047  37.355985
# 50                  Саларьевская ул., з/у 17, к. 83.2  55.613326  37.410726
# 51                               Десна дер., к. 9/1.2  55.528488  37.381432
# 52       Газопровод пос., к. Essense  сек. 8, этап 2   55.577403  37.476878
# 53                        вблизи Алхимово дер., д. 15  55.476592  37.505660
# 54    Московский пос., кв-л 70, уч. 78, к. 6  сек. 2   55.602167  37.346611
# 55  между Трёхполье ул., з/у 6 и Саларьевская ул.,...  55.613326  37.410726
# 56            Сосенское пос., Столбово дер., к. 3.8.1  55.551128  37.460062
# 57  Сосенское пос., вблизи Столбово дер., уч. 40/1...  55.548528  37.462561
# 58            Сосенское пос., Столбово дер., к. 3.5.1  55.551128  37.460062
# 60          Харлампиева ул., з/у 32  1 оч., сек. 1-2   55.550845  37.318936
# 62  Московский пос., кв-л 70, уч. 78, к. 1  сек. 2-5   55.602167  37.346611
# 63            Поляны ул., з/у 50Д, д. 18.2, к. 18.2.2  55.592256  37.474884
# 64   Московский пос., Картмазово дер., уч. 16/1, к. 5  55.615485  37.389209
# 65             Столбово дер., з/у 41/1Г, д. 5, к. 5.1  55.562266  37.471174
# 66                    Николо-Хованское дер., д. 5.1.4  55.595730  37.444636
# 67                   Александры Монаховой ул., к. 2.1  55.575994  37.471047
# 68             Сосенское пос., Коммунарка пос., к. 15  55.561134  37.473188
# 69             Столбово дер., з/у 41/1Г, д. 7, к. 7.3  55.561960  37.470860
#
#      ближайшее_метро  расстояние_км  расстояние_м
# 0         Тютчевская       0.381937           382
# 1        Рассказовка       0.063443            63
# 2            Пыхтино       1.448388          1448
# 4         Коммунарка       0.235279           235
# 6         Коммунарка       0.241175           241
# 8    Бунинская аллея       6.958350          6958
# 9          Румянцево       0.807538           808
# 11  Аэропорт Внуково       4.803320          4803
# 13        Тютчевская       0.566363           566
# 15           Пыхтино       1.448388          1448
# 16          Прокшино       1.243871          1244
# 20    Новомосковская       1.098432          1098
# 21  Аэропорт Внуково       4.803320          4803
# 22           Пыхтино       1.157447          1157
# 23    Новомосковская       1.315386          1315
# 24          Прокшино       3.367918          3368
# 25    Новомосковская       0.304388           304
# 26       Рассказовка       0.063443            63
# 27          Потапово       1.340224          1340
# 29           Пыхтино       1.448388          1448
# 31         Румянцево       0.788106           788
# 34          Прокшино       1.149558          1150
# 35          Прокшино       1.264940          1265
# 37        Коммунарка       0.668513           669
# 38          Прокшино       1.264940          1265
# 41         Румянцево       1.067462          1067
# 42       Рассказовка       0.556399           556
# 43  Аэропорт Внуково       6.131487          6131
# 44    Новомосковская       0.341444           341
# 45    Новомосковская       0.245427           245
# 46  Аэропорт Внуково       5.075604          5076
# 47       Филатов Луг       3.258717          3259
# 50         Саларьево       1.276990          1277
# 51    Новомосковская       6.366928          6367
# 52        Коммунарка       0.629598           630
# 53   Бунинская аллея       6.864403          6864
# 54       Рассказовка       3.628720          3629
# 55         Саларьево       1.276990          1277
# 56    Новомосковская       1.098432          1098
# 57    Новомосковская       1.348287          1348
# 58    Новомосковская       1.098432          1098
# 60  Аэропорт Внуково       6.567668          6568
# 62       Рассказовка       3.628720          3629
# 63      Корниловская       0.785094           785
# 64       Филатов Луг       1.953723          1954
# 65    Новомосковская       0.284228           284
# 66          Прокшино       1.264940          1265
# 67        Коммунарка       0.235279           235
# 68    Новомосковская       0.319764           320
# 69    Новомосковская       0.245427           245

# %%
fo.to_csv("geotometro.csv")

# %%
fo
# Out:
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2               Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 4                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 6                   Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# ..                                                 ...        ...        ...
# 411              Первый Московский мкр., к. 3  11 оч.   55.603047  37.355985
# 414                   Александры Монаховой ул., к. 1.3  55.571509  37.477044
# 418                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 419    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 420                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 2             Пыхтино       1.448388          1448
# 4          Коммунарка       0.235279           235
# 6          Коммунарка       0.241175           241
# ..                ...            ...           ...
# 411       Филатов Луг       3.258717          3259
# 414        Коммунарка       0.668513           669
# 418        Коммунарка       0.668513           669
# 419  Аэропорт Внуково       3.217480          3217
# 420        Коммунарка       0.917124           917
#
# [259 rows x 6 columns]

# %%
projects = pd.read_csv("clear_projects.csv")

projects_uniq = projects.drop_duplicates(subset=["адрес"], keep="first")

fp = fo.merge(
    projects_uniq[["адрес", "id_корпуса"]],
    left_on="Полный адресс",
    right_on="адрес",
    how="left"
).drop(columns=["адрес"])

fp
# Out:
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2               Льва Кассиля ул., д. 1, к. 1  фаза 17   55.637139  37.306423
# 3                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 4                   Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# ..                                                 ...        ...        ...
# 254              Первый Московский мкр., к. 3  11 оч.   55.603047  37.355985
# 255                   Александры Монаховой ул., к. 1.3  55.571509  37.477044
# 256                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 257    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 258                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м  \
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 2             Пыхтино       1.448388          1448
# 3          Коммунарка       0.235279           235
# 4          Коммунарка       0.241175           241
# ..                ...            ...           ...
# 254       Филатов Луг       3.258717          3259
# 255        Коммунарка       0.668513           669
# 256        Коммунарка       0.668513           669
# 257  Аэропорт Внуково       3.217480          3217
# 258        Коммунарка       0.917124           917
#
#                            id_корпуса
# 0    002b4f20e97d6ca8ac349b5e2e9e81d3
# 1    0076fc28a53eb506b7fc91475d31dea3
# 2                                 NaN
# 3    013e43142be6303646e81ccd28432986
# 4    01666d3450f19ef552996d68a8c8a537
# ..                                ...
# 254                               NaN
# 255  fc7dbe2d2ed10547d097316bf6a10e3b
# 256  fde1f8ad4322f757d44bdf4c634df283
# 257  fe3fbf2588f1c241871893ab71fee571
# 258  feb775e64315735a2d87a5a88937c947
#
# [259 rows x 7 columns]

# %%
clearfp = fp.dropna()
clearfp
# Out:
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 3                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 4                   Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# 5                           вблизи Алхимово дер., д. 8  55.475664  37.507313
# ..                                                 ...        ...        ...
# 253                      вблизи Середнево дер., к. 3.1  55.560682  37.292221
# 255                   Александры Монаховой ул., к. 1.3  55.571509  37.477044
# 256                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 257    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 258                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м  \
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 3          Коммунарка       0.235279           235
# 4          Коммунарка       0.241175           241
# 5     Бунинская аллея       6.958350          6958
# ..                ...            ...           ...
# 253  Аэропорт Внуково       5.182572          5183
# 255        Коммунарка       0.668513           669
# 256        Коммунарка       0.668513           669
# 257  Аэропорт Внуково       3.217480          3217
# 258        Коммунарка       0.917124           917
#
#                            id_корпуса
# 0    002b4f20e97d6ca8ac349b5e2e9e81d3
# 1    0076fc28a53eb506b7fc91475d31dea3
# 3    013e43142be6303646e81ccd28432986
# 4    01666d3450f19ef552996d68a8c8a537
# 5    0570feadb069224020f2abfe3a0a40e3
# ..                                ...
# 253  f6314d3d5d1cd943daa1aca9aed6a3c8
# 255  fc7dbe2d2ed10547d097316bf6a10e3b
# 256  fde1f8ad4322f757d44bdf4c634df283
# 257  fe3fbf2588f1c241871893ab71fee571
# 258  feb775e64315735a2d87a5a88937c947
#
# [215 rows x 7 columns]

# %%
deals_df = pd.read_csv("clear_deals.csv")

avg_ppsqm_by_building = (
    deals_df
    .assign(цена_за_кв_м=pd.to_numeric(deals_df["цена_за_кв_м"], errors="coerce"))
    .groupby("id_корпуса", as_index=False)
    .agg(avg_price_per_sqm=("цена_за_кв_м", "mean"))
)

# 2) присоединяем к таблице корпусов
projects_buildings_df = clearfp.merge(
    avg_ppsqm_by_building,
    on="id_корпуса",
    how="left"
)

# %%
projects_buildings_df
# Out:
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 3                   Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# 4                           вблизи Алхимово дер., д. 8  55.475664  37.507313
# ..                                                 ...        ...        ...
# 210                      вблизи Середнево дер., к. 3.1  55.560682  37.292221
# 211                   Александры Монаховой ул., к. 1.3  55.571509  37.477044
# 212                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 213    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 214                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м  \
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 2          Коммунарка       0.235279           235
# 3          Коммунарка       0.241175           241
# 4     Бунинская аллея       6.958350          6958
# ..                ...            ...           ...
# 210  Аэропорт Внуково       5.182572          5183
# 211        Коммунарка       0.668513           669
# 212        Коммунарка       0.668513           669
# 213  Аэропорт Внуково       3.217480          3217
# 214        Коммунарка       0.917124           917
#
#                            id_корпуса  avg_price_per_sqm
# 0    002b4f20e97d6ca8ac349b5e2e9e81d3      264727.152360
# 1    0076fc28a53eb506b7fc91475d31dea3      201641.898897
# 2    013e43142be6303646e81ccd28432986      240754.150776
# 3    01666d3450f19ef552996d68a8c8a537      214682.337704
# 4    0570feadb069224020f2abfe3a0a40e3      240921.345285
# ..                                ...                ...
# 210  f6314d3d5d1cd943daa1aca9aed6a3c8      211817.733946
# 211  fc7dbe2d2ed10547d097316bf6a10e3b      236715.208313
# 212  fde1f8ad4322f757d44bdf4c634df283      264385.147707
# 213  fe3fbf2588f1c241871893ab71fee571      173215.035148
# 214  feb775e64315735a2d87a5a88937c947      297271.842856
#
# [215 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(projects_buildings_df["расстояние_м"], projects_buildings_df["avg_price_per_sqm"])
plt.xlabel("Расстояние до метро, м")
plt.ylabel("Цена за кв. метр")
plt.title("Зависимость цены за кв. метр от расстояния до метро")
plt.show()

# %%
projects_buildings_df_con = (
    projects
    .groupby("id_корпуса")
    .agg(
        # стадия строительства корпус
        стадия_строительства=("стадия_строительства", "first"),

        # этажность дома
        building_floors_count=("этаж", "nunique"),

        # общее количество квартир в корпусе
        total_flats_in_building=("количество_лотов", "sum"),

        плановая_дата_рвэ=("плановая_дата_рвэ", "first"),
    )
    .reset_index()
)
projects_buildings_df_con
# Out:
#                            id_корпуса           стадия_строительства  \
# 0    002b4f20e97d6ca8ac349b5e2e9e81d3  Монтажные и отделочные работы
# 1    0076fc28a53eb506b7fc91475d31dea3  Монтажные и отделочные работы
# 2    0081bc4d4059f46b3b42276ba8aee782          Введен в эксплуатацию
# 3    009d5290e93e353bb27e3f01b505f5b7  Монтажные и отделочные работы
# 4    013e43142be6303646e81ccd28432986          Введен в эксплуатацию
# ..                                ...                            ...
# 414  fd01b8c0e5ea83c9252268d6806cf6e6  Монтажные и отделочные работы
# 415  fd11279466f6069c8fefd1baa5884d18          Введен в эксплуатацию
# 416  fde1f8ad4322f757d44bdf4c634df283          Введен в эксплуатацию
# 417  fe3fbf2588f1c241871893ab71fee571  Монтажные и отделочные работы
# 418  feb775e64315735a2d87a5a88937c947          Введен в эксплуатацию
#
#      building_floors_count  total_flats_in_building плановая_дата_рвэ
# 0                       16                      333        2025-12-31
# 1                       10                      235        2025-08-14
# 2                       18                      732        2025-08-21
# 3                       16                      703        2026-12-31
# 4                       18                      190        2025-06-17
# ..                     ...                      ...               ...
# 414                     21                      465        2027-03-31
# 415                     15                      535        2023-06-30
# 416                     19                      945        2025-05-30
# 417                     10                       68        2026-06-30
# 418                     15                      296        2024-08-23
#
# [419 rows x 5 columns]

# %%
# 2) присоединяем к таблице корпусов
projects_buildings_df = clearfp.merge(
    projects_buildings_df_con,
    on="id_корпуса",
    how="left"
)

projects_buildings_df
# Out:
#                                          Полный адресс        lat        lon  \
# 0          Сосенское пос., кв-л 26, з/у 3/3, к. 10.1.5  55.615527  37.482358
# 1    Рассказовка дер., Переделкино Ближнее мкр., кв...  55.633953  37.334340
# 2                     Александры Монаховой ул., к. 2.3  55.575994  37.471047
# 3                   Александры Монаховой ул., к. 6.1.2  55.575436  37.471679
# 4                           вблизи Алхимово дер., д. 8  55.475664  37.507313
# ..                                                 ...        ...        ...
# 210                      вблизи Середнево дер., к. 3.1  55.560682  37.292221
# 211                   Александры Монаховой ул., к. 1.3  55.571509  37.477044
# 212                   Александры Монаховой ул., к. 1.1  55.571509  37.477044
# 213    Марушкинское пос., 33 кв-л, уч. 3, д. 3, к. 3.4  55.599195  37.238568
# 214                      Николо-Хованское дер., д. 8.1  55.582970  37.468123
#
#       ближайшее_метро  расстояние_км  расстояние_м  \
# 0          Тютчевская       0.381937           382
# 1         Рассказовка       0.063443            63
# 2          Коммунарка       0.235279           235
# 3          Коммунарка       0.241175           241
# 4     Бунинская аллея       6.958350          6958
# ..                ...            ...           ...
# 210  Аэропорт Внуково       5.182572          5183
# 211        Коммунарка       0.668513           669
# 212        Коммунарка       0.668513           669
# 213  Аэропорт Внуково       3.217480          3217
# 214        Коммунарка       0.917124           917
#
#                            id_корпуса           стадия_строительства  \
# 0    002b4f20e97d6ca8ac349b5e2e9e81d3  Монтажные и отделочные работы
# 1    0076fc28a53eb506b7fc91475d31dea3  Монтажные и отделочные работы
# 2    013e43142be6303646e81ccd28432986          Введен в эксплуатацию
# 3    01666d3450f19ef552996d68a8c8a537  Монтажные и отделочные работы
# 4    0570feadb069224020f2abfe3a0a40e3          Введен в эксплуатацию
# ..                                ...                            ...
# 210  f6314d3d5d1cd943daa1aca9aed6a3c8          Введен в эксплуатацию
# 211  fc7dbe2d2ed10547d097316bf6a10e3b          Введен в эксплуатацию
# 212  fde1f8ad4322f757d44bdf4c634df283          Введен в эксплуатацию
# 213  fe3fbf2588f1c241871893ab71fee571  Монтажные и отделочные работы
# 214  feb775e64315735a2d87a5a88937c947          Введен в эксплуатацию
#
#      building_floors_count  total_flats_in_building плановая_дата_рвэ
# 0                       16                      333        2025-12-31
# 1                       10                      235        2025-08-14
# 2                       18                      190        2025-06-17
# 3                       18                      174        2026-03-31
# 4                       13                      443        2023-08-01
# ..                     ...                      ...               ...
# 210                     15                      275        2023-09-21
# 211                     18                      190        2025-05-30
# 212                     19                      945        2025-05-30
# 213                     10                       68        2026-06-30
# 214                     15                      296        2024-08-23
#
# [215 rows x 11 columns]

# %%
plt.figure()
plt.scatter(projects_buildings_df["расстояние_м"], projects_buildings_df["total_flats_in_building"])
plt.xlabel("Расстояние до метро, м")
plt.ylabel("Цена за кв. метр")
plt.title("Зависимость цены за кв. метр от расстояния до метро")
plt.show()
